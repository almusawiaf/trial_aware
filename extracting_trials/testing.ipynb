# %%
import json
import re

with open("../data/10000_trials/structured_clinical_trials.json") as f:
    trials = json.load(f)

icd9_shaped = re.compile(r'^\d')  # starts with a digit -> looks like ICD-9, not ICD-10
count_icd9_shaped = 0
count_total_diagnosis = 0
examples = []

for t in trials:
    for c in t["criteria"]:
        if c["entity_type"] == "diagnosis":
            count_total_diagnosis += 1
            code = c["entity_code"]
            if icd9_shaped.match(code):
                count_icd9_shaped += 1
                if len(examples) < 10:
                    examples.append((code, c["raw_entity"][:60]))

print(f"Diagnosis codes that look like ICD-9 (not ICD-10): {count_icd9_shaped}/{count_total_diagnosis}")
for code, text in examples:
    print(f"  {code}: {text}")
# Out:
# Diagnosis codes that look like ICD-9 (not ICD-10): 2231/5090
#   64670: 2. No chronic underlying diseases (including liver, kidney,
#   04149: 3. No use of antibiotics or probiotics, and no history of ac
#   2307: 3. History of inflammatory bowel disease (including ulcerati
#   1543: 4. Patients with malignant tumors currently receiving chemot
#   7615: * Pregnancy, breastfeeding, or planning to become pregnant d
#   36901: * Hearing impairment or physical disability that would subst
#   99932: * Prehypertensive individuals with systolic blood pressure (
#   64880: * Fasting glucose ≤125 mg/dL.
#   99932: * Not taking blood pressure-lowering and/or cholesterol-lowe
#   99932: * Individuals currently taking antibiotics, nonsteroidal ant
